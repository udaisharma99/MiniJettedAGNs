# %%
from data_structures2 import Source
import logging
from astropy.table import vstack
from astroquery.vizier import Vizier
from astropy.table import Table
from data_structures import coreG_catalogue, fr0_catalogue
import pandas as pd
from pathlib import Path
# Out:
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]

# %%
log = logging.getLogger(__name__)
logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s|%(name)s|%(message)s",
    datefmt="%m/%d/%Y %I:%M:%S %p",
)

# %%
# Loading tables with only required columns
##Import Source and Counterpart Catalogs
nagar_2005 = Vizier(columns=["**"], row_limit=-1).get_catalogs("J/A+A/435/521")
fr0cat = Vizier(columns=["**"], row_limit=-1).get_catalogs("J/A+A/609/A1")

# %%
fr0cat[0]

# %%
for name, _type in zip(
    nagar_2005[0]["Name"],
    nagar_2005[0]["AType"],
):
    if 'L' in _type:
        source = Source(name)
        source.write_catalogue_row(coreG_catalogue)
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/astropy/table/table.py:3220: UserWarning: Units from inserted quantities will be ignored.
#   self.insert_row(len(self), vals, mask)
# /Users/usharma/Documents/GitHub/MiniJettedAGNs/data_structures2.py:232: RuntimeWarning: divide by zero encountered in log10
#   self.LogL_OIII = np.log10(L_OIII.to_value("erg s-1"))
# 10/31/2025 03:48:21 PM|utils|2 SDSS counterparts found for NGC2841 by SIMBAD. Taking the first one: SDSS J092202.67+505835.9
# 10/31/2025 03:48:21 PM|utils|full list of counterparts: ['SDSS J092202.67+505835.9' 'SDSS J092202.66+505835.7'] please check on SIMBAD!
# 10/31/2025 03:48:24 PM|utils|2 SDSS counterparts found for NGC3190 by SIMBAD. Taking the first one: SDSS J101805.65+214956.1
# 10/31/2025 03:48:24 PM|utils|full list of counterparts: ['SDSS J101805.65+214956.1' 'SDSS J101805.66+214956.1'] please check on SIMBAD!
# 10/31/2025 03:48:26 PM|utils|2 SDSS counterparts found for NGC3226 by SIMBAD. Taking the first one: SDSS J102326.99+195354.7
# 10/31/2025 03:48:26 PM|utils|full list of counterparts: ['SDSS J102326.99+195354.7' 'SDSS J102326.99+195354.6'] please check on SIMBAD!
# 10/31/2025 03:48:29 PM|utils|2 SDSS counterparts found for NGC3379 by SIMBAD. Taking the first one: SDSS J104749.60+123453.9
# 10/31/2025 03:48:29 PM|utils|full list of counterparts: ['SDSS J104749.60+123453.9' 'SDSS J104749.61+123454.1'] please check on SIMBAD!
# 10/31/2025 03:48:30 PM|utils|2 SDSS counterparts found for NGC3433 by SIMBAD. Taking the first one: SDSS J105203.87+100853.9
# 10/31/2025 03:48:30 PM|utils|full list of counterparts: ['SDSS J105203.87+100853.9' 'SDSS J105203.86+100853.9'] please check on SIMBAD!
# 10/31/2025 03:48:37 PM|utils|4 SDSS counterparts found for NGC3780 by SIMBAD. Taking the first one: SDSS J113922.35+561614.3
# 10/31/2025 03:48:37 PM|utils|full list of counterparts: ['SDSS J113922.35+561614.3' 'SDSS J113922.34+561614.6'
#  'SDSS J113922.36+561614.3' 'SDSS J113922.36+561614.4'] please check on SIMBAD!
# 10/31/2025 03:48:41 PM|utils|3 SDSS counterparts found for NGC4036 by SIMBAD. Taking the first one: SDSS J120126.75+615344.8
# 10/31/2025 03:48:41 PM|utils|full list of counterparts: ['SDSS J120126.75+615344.8' 'SDSS J120126.73+615345.0'
#  'SDSS J120126.74+615344.7'] please check on SIMBAD!
# 10/31/2025 03:48:44 PM|utils|2 SDSS counterparts found for NGC4261 by SIMBAD. Taking the first one: SDSS J121923.21+054929.7
# 10/31/2025 03:48:44 PM|utils|full list of counterparts: ['SDSS J121923.21+054929.7' 'SDSS J121923.22+054929.7'] please check on SIMBAD!
# 10/31/2025 03:48:49 PM|utils|2 SDSS counterparts found for NGC4374 by SIMBAD. Taking the first one: SDSS J122503.74+125312.8
# 10/31/2025 03:48:49 PM|utils|full list of counterparts: ['SDSS J122503.74+125312.8' 'SDSS J122503.03+125349.1'] please check on SIMBAD!
# 10/31/2025 03:48:50 PM|utils|2 SDSS counterparts found for NGC4394 by SIMBAD. Taking the first one: SDSS J122555.63+181250.1
# 10/31/2025 03:48:50 PM|utils|full list of counterparts: ['SDSS J122555.63+181250.1' 'SDSS J122600.09+181320.6'] please check on SIMBAD!
# 10/31/2025 03:48:51 PM|utils|2 NVSS counterparts found for NGC4450 by SIMBAD. Taking the first one: NVSS J122829+170502
# 10/31/2025 03:48:51 PM|utils|full list of counterparts: ['NVSS J122829+170502' 'NVSS B122558+172138'] please check on SIMBAD!
# 10/31/2025 03:48:53 PM|utils|2 SDSS counterparts found for NGC4486 by SIMBAD. Taking the first one: SDSS J123049.41+122328.1
# 10/31/2025 03:48:53 PM|utils|full list of counterparts: ['SDSS J123049.41+122328.1' 'SDSS J123047.55+122318.0'] please check on SIMBAD!
# 10/31/2025 03:48:53 PM|utils|3 NVSS counterparts found for NGC4486 by SIMBAD. Taking the first one: NVSS B122817+124004
# 10/31/2025 03:48:53 PM|utils|full list of counterparts: ['NVSS B122817+124004' 'NVSS J123049+122323' 'NVSS J123049+122321'] please check on SIMBAD!
# 10/31/2025 03:48:57 PM|utils|3 SDSS counterparts found for NGC4579 by SIMBAD. Taking the first one: SDSS J123743.52+114905.4
# 10/31/2025 03:48:57 PM|utils|full list of counterparts: ['SDSS J123743.52+114905.4' 'SDSS J123743.53+114905.5'
#  'SDSS J123745.44+114900.3'] please check on SIMBAD!
# 10/31/2025 03:48:57 PM|utils|2 NVSS counterparts found for NGC4579 by SIMBAD. Taking the first one: NVSS J123743+114908
# 10/31/2025 03:48:57 PM|utils|full list of counterparts: ['NVSS J123743+114908' 'NVSS B123512+120537'] please check on SIMBAD!
# 10/31/2025 03:48:59 PM|utils|3 SDSS counterparts found for NGC4596 by SIMBAD. Taking the first one: SDSS J123955.94+101034.0
# 10/31/2025 03:48:59 PM|utils|full list of counterparts: ['SDSS J123955.94+101034.0' 'SDSS J123957.75+101020.8'
#  'SDSS J123955.95+101034.1'] please check on SIMBAD!
# 10/31/2025 03:48:59 PM|utils|2 SDSS counterparts found for NGC4636 by SIMBAD. Taking the first one: SDSS J124249.82+024116.0
# 10/31/2025 03:48:59 PM|utils|full list of counterparts: ['SDSS J124249.82+024116.0' 'SDSS J124249.82+024115.9'] please check on SIMBAD!
# 10/31/2025 03:49:00 PM|utils|2 SDSS counterparts found for NGC4651 by SIMBAD. Taking the first one: SDSS J124342.64+162335.9
# 10/31/2025 03:49:00 PM|utils|full list of counterparts: ['SDSS J124342.64+162335.9' 'SDSS J124343.61+162347.4'] please check on SIMBAD!
# 10/31/2025 03:49:03 PM|utils|2 SDSS counterparts found for NGC4762 by SIMBAD. Taking the first one: SDSS J125255.97+111351.5
# 10/31/2025 03:49:03 PM|utils|full list of counterparts: ['SDSS J125255.97+111351.5' 'SDSS J125254.66+111325.8'] please check on SIMBAD!
# 10/31/2025 03:49:11 PM|utils|2 SDSS counterparts found for NGC5363 by SIMBAD. Taking the first one: SDSS J135607.27+051514.7
# 10/31/2025 03:49:11 PM|utils|full list of counterparts: ['SDSS J135607.27+051514.7' 'SDSS J135606.81+051515.1'] please check on SIMBAD!
# 10/31/2025 03:49:13 PM|utils|2 SDSS counterparts found for NGC5377 by SIMBAD. Taking the first one: SDSS J135616.66+471408.5
# 10/31/2025 03:49:13 PM|utils|full list of counterparts: ['SDSS J135616.66+471408.5' 'SDSS J135616.67+471408.5'] please check on SIMBAD!
# 10/31/2025 03:49:14 PM|utils|2 SDSS counterparts found for NGC5395 by SIMBAD. Taking the first one: SDSS J135837.98+372528.1
# 10/31/2025 03:49:14 PM|utils|full list of counterparts: ['SDSS J135837.98+372528.1' 'SDSS J135837.97+372528.2'] please check on SIMBAD!
# 10/31/2025 03:49:16 PM|utils|4 SDSS counterparts found for NGC5485 by SIMBAD. Taking the first one: SDSS J140711.33+550006.2
# 10/31/2025 03:49:16 PM|utils|full list of counterparts: ['SDSS J140711.33+550006.2' 'SDSS J140711.35+550005.9'
#  'SDSS J140711.35+550005.8' 'SDSS J140711.34+550005.9'] please check on SIMBAD!
# 10/31/2025 03:49:17 PM|utils|3 SDSS counterparts found for NGC5631 by SIMBAD. Taking the first one: SDSS J142633.30+563457.4
# 10/31/2025 03:49:17 PM|utils|full list of counterparts: ['SDSS J142633.30+563457.4' 'SDSS J142633.29+563457.4'
#  'SDSS J142633.28+563457.7'] please check on SIMBAD!
# 10/31/2025 03:49:19 PM|utils|2 SDSS counterparts found for NGC5850 by SIMBAD. Taking the first one: SDSS J150707.68+013239.2
# 10/31/2025 03:49:19 PM|utils|full list of counterparts: ['SDSS J150707.68+013239.2' 'SDSS J150707.69+013239.3'] please check on SIMBAD!
# 10/31/2025 03:49:19 PM|utils|2 NVSS counterparts found for NGC5850 by SIMBAD. Taking the first one: NVSS J150704+013308
# 10/31/2025 03:49:19 PM|utils|full list of counterparts: ['NVSS J150704+013308' 'NVSS J150708+013312'] please check on SIMBAD!
# 10/31/2025 03:49:20 PM|utils|2 SDSS counterparts found for NGC5879 by SIMBAD. Taking the first one: SDSS J150946.76+570000.8
# 10/31/2025 03:49:20 PM|utils|full list of counterparts: ['SDSS J150946.76+570000.8' 'SDSS J150946.76+570000.7'] please check on SIMBAD!

# %%
coreG_catalogue
# Out:
# <Table length=97>
# SOURCE_NAME         RA         ...   SWIFT HR2 L_err      SWIFT HR2 U_err
#                    deg         ...
#     str7         float64       ...       float64              float64
# ----------- ------------------ ... -------------------- -------------------
#       IC239     39.11594251433 ...  -0.2020999938249588 0.16200000047683716
#      IC1727 26.874541666666662 ... -0.39730000495910645 0.46650001406669617
#      NGC266     12.44922907833 ... -0.28299999237060547 0.27379998564720154
#      NGC315 14.453680600416666 ... -0.04129999876022339 0.04129999876022339
#      NGC404           17.36259 ... -0.24560000002384186  0.6689000129699707
#      NGC428 18.232120833333333 ... -0.07410000264644623  0.2985999882221222
#      NGC474     20.02786271688 ... -0.36309999227523804  0.4544000029563904
#      NGC718     28.30535093551 ...  -0.5475999712944031  0.5092999935150146
#      NGC777 30.062110711560003 ... -0.20270000398159027 0.26190000772476196
#         ...                ... ...                  ...                 ...
#     NGC5982  234.6657416666667 ... -0.19460000097751617 0.04540000110864639
#     NGC5985 234.90439405924002 ... -0.19460000097751617 0.04540000110864639
#     NGC6340    257.60347760599 ...   -0.179299995303154 0.16779999434947968
#     NGC6500  268.9990924535417 ...  -0.2847999930381775 0.46709999442100525
#     NGC6703    281.82840277515 ...  -0.5002999901771545 0.40720000863075256
#     NGC7217    331.96832694816 ...  -0.3917999863624573 0.33070001006126404
#     NGC7626  350.1771833333333 ...  -0.1273999959230423  0.1639000028371811
#     NGC7742    356.06563920807 ...    -0.36039999127388 0.07209999859333038
#     NGC7814 0.8122791666666666 ...  -0.2126999944448471 0.10189999639987946

# %%
fr0cat[0]

# %%
for row in fr0cat[0]:
    name = row['SimbadName']
    source = Source(name)
    source.write_catalogue_row(fr0_catalogue)

# %%
fr0_catalogue

# %%
fr0_catalogue = fr0_catalogue.table 
path1 = Path("./")
path1.mkdir(exist_ok=True, parents=True)
fr0_catalogue.write(
    path1 / "fr0_catalogue.fits", overwrite=True
)
coreG_catalogue = coreG_catalogue.table
path2 = Path("./")
path2.mkdir(exist_ok=True, parents=True)
coreG_catalogue.write(
    path2 / "coreG_catalogue.fits", overwrite=True
)
fr0_coreG_catalogue = vstack([fr0_catalogue,coreG_catalogue])
path = Path("./")
path.mkdir(exist_ok=True, parents=True)
fr0_coreG_catalogue.write(
    path / "fr0_coreG_catalogue.fits", overwrite=True
)

import IPython; IPython.embed()
